# %%
import numpy as np
from tools import SparseGroupLasso
from sklearn.linear_model import *

import matplotlib as mpl

mpl.use('TkAgg')
import matplotlib.pyplot as plt
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 12}
mpl.rc('font', **font)

# %% [markdown]
# ## Step 0. Load PDS-specific data

# %%
fm = np.load('../data/fm.npy')
e = np.load('../data/e.npy')
e = e.reshape(-1,1)
groups = np.load('../data/groups.npy')
ZERO_CLUSTER = 0
FIRST_POINT_CLUSTER = 1 
LAST_POINT_CLUSTER = 8

# %% [markdown]
# ## Step 1. Generate wraparound functions for hyperparameter optimization

# %%
CUTOFF = 1E-5 

def sgl_hyperparameter_optimization(alpha, lambda_mixing, groups,
                                    X_train, X_test, 
                                    y_train, y_test):
    E0 = np.mean(y_train)
    E1_lasso_CV = LassoCV(fit_intercept = True).fit(
        X_train[:, FIRST_POINT_CLUSTER:LAST_POINT_CLUSTER], y_train-E0)
    E1 = E1_lasso_CV.predict(
        X_train[:, FIRST_POINT_CLUSTER:LAST_POINT_CLUSTER]).reshape(-1,1)
    E1_predict = E1_lasso_CV.predict(X_test[:, FIRST_POINT_CLUSTER:LAST_POINT_CLUSTER]).reshape(-1,1)
    
    y_train_remainder = y_train - E0 - E1
    y_test_remainder = y_test - E0 - E1_predict
    
    sgl = SparseGroupLasso(groups=groups[LAST_POINT_CLUSTER:],
                          lambd=lambda_mixing)
    sgl.set_params(alpha)
    sgl.fit(X_train[:, LAST_POINT_CLUSTER:], 
            y_train_remainder)
    
    y_train_predict = np.dot(X_train[:, LAST_POINT_CLUSTER:], sgl.coef_)
    y_test_predict = np.dot(X_test[:, LAST_POINT_CLUSTER:], sgl.coef_)
    
    rmse_train = np.sqrt(mean_squared_error(y_train_predict.ravel(), y_train_remainder.ravel()))
    rmse_test = np.sqrt(mean_squared_error(y_test_predict.ravel(), y_test_remainder.ravel()))
    no_features = len(np.where(np.abs(sgl.coef_) > CUTOFF)[0])

    return [rmse_train, rmse_test, no_features]

# %% [markdown]
# ## Step 2. Run many trials. There will be warnings because we are scanning through hyperparameters which may not be optimal solutions.

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

TRIALS = 5 # reduced from 50 to save time in the example run
TEST_SIZE = 0.2
LAMBDA_MIXING = 0.5

train, test, features = [], [], []
hyperparameters = np.logspace(-4,-2)
for penalty in hyperparameters: 
    penalty_train, penalty_test, penalty_features = [], [], [] 
    for _ in range(TRIALS):
        X_train, X_test, y_train, y_test = train_test_split(fm, e, test_size=TEST_SIZE)
        results = sgl_hyperparameter_optimization(penalty, LAMBDA_MIXING, groups,
                                                  X_train, X_test, y_train, y_test)
        
        [rmse_train, rmse_test, no_features] = results
        penalty_train.append(rmse_train)
        penalty_test.append(rmse_test)
        penalty_features.append(no_features)
    train.append(np.mean(penalty_train))
    test.append(np.mean(penalty_test))
    features.append(np.mean(penalty_features))

fig = plt.figure()
ax1 = fig.add_subplot(111)
ax2 = ax1.twinx()
ax1.plot(hyperparameters, train, color = 'green', marker = 'x')
ax1.plot(hyperparameters, test, color = 'red', marker = 'x')
ax2.plot(hyperparameters, features, color = 'orange', marker = 'x')
ax2.set_ylim([0, 450])
ax2.axhline(y=428, ls = '--', color = 'black')
plt.show()
# Out:
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.
-05
#   model = cd_fast.enet_coordinate_descent(
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0034387899360892593, tolerance: 9.350961763395814e-05
#   model = cd_fast.enet_coordinate_descent(
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007317046459757837, tolerance: 0.00041708199613651315
#   model = cd_fast.enet_coordinate_descent(
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.19125737071028315, tolerance: 0.00040826121976207327
#   model = cd_fast.enet_coordinate_descent(
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.13262791907539917, tolerance: 0.0003558821045596928
#   model = cd_fast.enet_coordinate_descent(
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.11865246938777663, tolerance: 0.0002875326766047109
#   model = cd_fast.enet_coordinate_descent(
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.002421310007914901, tolerance: 0.0002780020618684329
#   model = cd_fast.enet_coordinate_descent(
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.11993240607181255, tolerance: 0.00020167258613379888
#   model = cd_fast.enet_coordinate_descent(
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0009048115271526047, tolerance: 0.00018163951871039683
#   model = cd_fast.enet_coordinate_descent(
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0022353603477389683, tolerance: 0.00045890609281396525
#   model = cd_fast.enet_coordinate_descent(
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.09707844752188066, tolerance: 0.00044932709369364856
#   model = cd_fast.enet_coordinate_descent(
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.15180564802524144, tolerance: 0.0003967274057016544
#   model = cd_fast.enet_coordinate_descent(
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04455596301585496, tolerance: 0.00030067633475089605
#   model = cd_fast.enet_coordinate_descent(
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0113996117117392, tolerance: 0.00021253642162613026
#   model = cd_fast.enet_coordinate_descent(
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3690455758036646, tolerance: 0.00048186879216535083
#   model = cd_fast.enet_coordinate_descent(
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.16132488208272644, tolerance: 0.00042361419139592445
#   model = cd_fast.enet_coordinate_descent(
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2118528960858561, tolerance: 0.0003317504861545833
#   model = cd_fast.enet_coordinate_descent(
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.015319752659112007, tolerance: 0.00021083050614418503
#   model = cd_fast.enet_coordinate_descent(
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.002424348481800731, tolerance: 6.975215099874654e-05
#   model = cd_fast.enet_coordinate_descent(
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02174235570366534, tolerance: 0.00047648422491464556
#   model = cd_fast.enet_coordinate_descent(
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.08965062506539878, tolerance: 0.00031753631497298914
#   model = cd_fast.enet_coordinate_descent(
# ...
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Users/jhyang/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3445: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# ### Running the above results in a hyperparameter of $\approx \alpha = 0.002$ for a mixing of $\lambda = 0.5$ with train/test RMSE of $0.082/0.065$ eV/prim for 100 total  features.

# %% [markdown]
# ## Step 3. Save all coefficients

# %%
ALPHA = 0.002
X_train, X_test, y_train, y_test = train_test_split(fm, e, 
                                                    test_size=TEST_SIZE)
        
E0 = np.mean(y_train)
E1_lasso_CV = LassoCV(fit_intercept = True).fit(
        X_train[:, FIRST_POINT_CLUSTER:LAST_POINT_CLUSTER], y_train.ravel()-E0)
E1 = E1_lasso_CV.predict(
        X_train[:, FIRST_POINT_CLUSTER:LAST_POINT_CLUSTER]).reshape(-1,1)
E1_predict = E1_lasso_CV.predict(X_test[:, FIRST_POINT_CLUSTER:LAST_POINT_CLUSTER]).reshape(-1,1)
    
y_train_remainder = y_train - E0 - E1
y_test_remainder = y_test - E0 - E1_predict
    
sgl = SparseGroupLasso(groups=groups[LAST_POINT_CLUSTER:],
                          lambd=LAMBDA_MIXING)
sgl.set_params(ALPHA)
sgl.fit(X_train[:, LAST_POINT_CLUSTER:], 
            y_train_remainder)
y_train_predict = np.dot(X_train[:, LAST_POINT_CLUSTER:], sgl.coef_)
y_test_predict = np.dot(X_test[:, LAST_POINT_CLUSTER:], sgl.coef_)

print ('TRAINING ERROR:', np.sqrt(mean_squared_error(y_train_predict, y_train_remainder.ravel())))
print ('TESTING ERROR:', np.sqrt(mean_squared_error(y_test_predict, y_test_remainder.ravel())))
coef = np.concatenate(([E0+E1_lasso_CV.intercept_], E1_lasso_CV.coef_, 
                      sgl.coef_), axis=0)
print ('NO. COEFS:', len(np.where(np.abs(coef)>CUTOFF)[0]))
# Out:
# TRAINING ERROR: 0.08199731677975394
# TESTING ERROR: 0.06691736705558192
# NO. COEFS: 98

# %%
np.save('sgl_eci.npy', coef)
